# %% [raw]
# ---
# categories:
# - c1
# - c2
# description: Fast AI in Docker Container
# key1: value1
# key2: value2
# output-file: docker.html
# title: Docker
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ## Definitions

# %% [markdown]
# - Dockerfile
#   - Blueprint for building a docker image
# - Image
#   - Template for running a docker containers
# - Container
#   - Running process

# %% [markdown]
# ## View Docker Images

# %% [markdown]
# ```sh
# docker images
# ```

# %% [markdown]
# ## View Dockers Containers Running

# %% [markdown]
# ```sh
# docker ps
# ```

# %% [markdown]
# ## Docker File

# %% [markdown]
# FILE _image_ - base image ex. ubuntu, node:12
#
# WORKDIR _filename_ - like when you cd into a directory
#
# **_every step from now is considered layes_**
#
# COPY _filename_ _location_ - ex. COPY package*.json ./
#
# RUN _npm install_ - exec commands
#
# COPY . . - copy all the file in directory into the container

# %% [markdown]
# ## .dockerignore
#
# > just like a git ignore file
