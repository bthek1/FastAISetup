# %% [raw]
# ---
# description: Details on setting up Pytorch Setup
# output-file: pytorchsetup.html
# title: Pytorch Setup
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ## Computer Setup
#
# - Uninstall Onedrive
# - Install:
#
#   > Matlab
#
#   > Git
#
#   > vscode
#
#   > docker
#
#   > anaconda
#
#   > nvidia
#   > - toolit
#   > - cuda
#   > - cudnn

# %% [markdown]
# ## Program Setup
#
# - nbdev - see nbdev page
# - quarto - see quarto page
# - jupyter lab - see nbdev page
#
# - Optional installs
# > - vim
# ```sh
#  - conda install -c conda-forge vim
# ```
# > grep
# ```sh
#  - conda install -c conda-forge grep
# ```
