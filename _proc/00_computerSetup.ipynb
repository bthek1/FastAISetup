# %% [raw]
# ---
# description: Details on setting up Computer Setup
# output-file: computersetup.html
# title: Computer Setup
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ## Uninstalls
# - OneDrive

# %% [markdown]
# ## Installs
# - Git
# - Vscode
# - Docker
# - Anaconda
# - WSL
# - Ubuntu

# %% [markdown]
# ## Run Cuda 11.8

# %% [markdown]
# > It has to be cuda 11.8

# %% [markdown]
# ## Download WSL - Linux environment for Windows

# %% [markdown]
# - goto powershell
# ```sh
# wsl --install
# ```

# %% [markdown]
# - o see a list of available Linux distributions available for download through the online store
# ```sh
# wsl -l -o
# ```

# %% [markdown]
# - to download a Linux distribution
# ```sh
# wsl --install -d <Distribution Name>
# ```

# %% [markdown]
# ## Run Fastsetup in linux file

# %% [markdown]
# ```sh
# gh repo clone fastai/fastsetup
# ```

# %% [markdown]
# > Read README.txt

# %% [markdown]
# ```sh
# cd fastsetup
# ```

# %% [markdown]
# give files permission to run
# ```sh
# chmod +x *
# ```

# %% [markdown]
# ```sh
# sudo ./ubuntu-wsl.sh
# ```

# %% [markdown]
# ```sh
# ./setup-conda.sh
# ```

# %% [markdown]
# ```sh
# . ~/.bashrc
# ```

# %% [markdown]
# ```sh
# conda install -yq mamba
# ```
