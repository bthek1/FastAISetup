# %% [raw]
# ---
# description: Details on setting up nbdev Setup
# output-file: nbdevsetup.html
# title: Nbdev Setup
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# # Installation
#
# - Python
# - A Python package manager: we recommend conda or pip - download anaconda
# - Jupyter Notebook - see below
# - nbdev - see below
# - Quarto - see quarto setup

# %% [markdown]
# ### To get Jupyter labs
# ```sh
# pip install jupyterlab
# ```

# %% [markdown]
# ### To launch jupyter labs
# ```sh
# jupyter lab
# ```

# %% [markdown]
# Install nbdev
