# %% [raw]
# ---
# description: Details on setting up conda Setup
# output-file: conda_setup.html
# title: Conda Setup
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ## Fast Setup

# %% [markdown]
# ```sh
# gh repo clone fastai/fastsetup
# ```

# %% [markdown]
# > to list conda envs
# ```sh
# conda env list
# ```

# %% [markdown]
# ## To create basic conda env

# %% [markdown]
# After running ./setup-conda.sh, create conda environment
#
# ```sh
# conda create -n <name> python
# ```

# %% [markdown]
# ## To remove conda env

# %% [markdown]
# ```sh
# conda remove --name myenv --all
# ```

# %% [markdown]
# ## To build conda env with environment file

# %% [markdown]
# ```sh
# conda env create -n <name> -f environment.yml
# ```

# %% [markdown]
# ```sh
# mamba env create -n cfast -f cfast.yml
# ```

# %% [markdown]
# - for creating environment files
# ```sh
# conda env export > environment.yml
# ```

# %% [markdown]
# ## To clone an env

# %% [markdown]
# ```sh
# conda create --name <clone name> --clone <env name>
# ```

# %% [markdown]
# ## To create a spec list file

# %% [markdown]
# ```sh
# conda list --explicit > spec-file.txt
# ```

# %% [markdown]
# To use the spec file to install its listed packages into an existing environment:
#
# ```sh
# conda install --name myenv --file spec-file.txt
# ```

# %% [markdown]
# ## To clean Mamba cache

# %% [markdown]
# ```sh
# mamba clean --yes --all
# ```
